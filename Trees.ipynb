# %% [markdown]
# # Trees
# #### Notebook by Mitch

# %% [markdown]
# The purpose of this notebook is to find the amount of trees in each neighborhood, and sort the neighborhoods from highest to lowest by their number of trees. We will use this ranking for the final analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('treesData.csv', sep=',', dtype={data.columns[2]: str})
treesCount = data.groupby('neighborhood')['_id'].count()
treesCount = treesCount.sort_values()

# %%
# Ploting data using matplotlib.pyplot

# V creates and formats plot to be useful
plt.figure(figsize=(12, 8))
trashCount.sort_values().plot(kind='bar', color='green')
plt.title('Trees in Pittsbutrgh Neighborhood')
plt.xlabel('Pittsburgh Neighborhood')
plt.ylabel('Trees Count')
plt.xticks(rotation=270)
plt.tight_layout()

# Plot-A-Semseme
plt.show()

# %% [markdown]
# # Conclusion
# Trees make meaningful impacts on a neighborhoods beauty by adding natural charm and color to the surroundings. This is done by leaves, flowers, and changing colors through the seasons bring life and variety to streets and yards. Trees help soften the look of buildings and roads making spaces more green and incorperated. These changes allow for also a preservation of natural beauty with their key role in reducing land erosion, giving more water saturation to reduce large scale water damage, and giving a solid base to allow for more life to sprout from the enviroment created by trees.
