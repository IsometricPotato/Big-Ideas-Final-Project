# %% [markdown]
# # Trash Submetric

# %% [markdown]
# This notebook ranks the neighborhoods by how many trash cans each neighborhood has, because the more trash cans, the less littering there is (in theory).

# %% [markdown]
# **Importing**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
data = pd.read_csv('trashData.csv', sep=',')

trashCount = data.groupby('neighborhood')['container_id'].count()
trashCount = trashCount.sort_values()

# %% [markdown]
# **Plot**

# %%
#Creates plot within a specified size
plt.figure(figsize=(12, 8))

#Modifies plot to be more descriptive
trashCount.sort_values().plot(kind='bar', color='skyblue')
plt.title('Amount of trash cans per neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('# of trash cans')
plt.xticks(rotation=90)
plt.tight_layout()

#Displays plot based on number of trashcans
plt.show()

# %% [markdown]
# # Conclusion
# Shadyside ranks highest for amount of smart trash cans inside of a neighborhood making it the most bauetiful because smart trashcans help make neighborhoods more beautiful by keeping streets cleaner and more organized. These smart trashcans quipped with sensors that detect when they are full, these bins reduce the chances of overflowing garbage, which helps minimize litter, unpleasant smells, and pests.
